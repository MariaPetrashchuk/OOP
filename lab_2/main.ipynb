# %%
from datetime import datetime
name = "Maria"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Maria start programming at 2025-11-01 18:47:54.078829. Lviv is the best city!

# %% [markdown]
# Моя перша програма

# %% [markdown]
# # 🤖 Перша програма, створена AI
#
# Нижче наведено приклад першої програми, яку міг би написати штучний інтелект для початківця:

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# Створити загаловок 3 рівня має бути не номерований список з двох пунктів і у 1 пункті має бути гіперпосилання на файл з вашого репозиторію.
